# %% [markdown]
# ![image.png](attachment:52e83941-81e9-4251-9718-00dd4bc43852.png)

# %% [markdown]
# ![image.png](attachment:804036d9-b500-4b64-8bea-d4ea54fab73b.png)

# %% [markdown]
# # Don't forget Epsilon

# %%
print("protect log with epsilon")
# Out:
# protect log from epsilon
