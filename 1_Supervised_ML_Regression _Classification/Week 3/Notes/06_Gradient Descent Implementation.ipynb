# %% [markdown]
# # Gradient Descent Implementation

# %% [markdown]
# How to find a choice of the paramters w, b ?
#
# if you do so , you can give a new input x for example tumor size and age, then the model can make a prediction or try to estimate the probabilty that the label y is 1
# ![image.png](attachment:8ff9ec8b-62df-4745-a826-d037e24abffc.png)

# %% [markdown]
# ## Gradient Descent for logistic regression
# ![image.png](attachment:6954362c-0747-4933-81b2-53f265ad3492.png)

# %% [markdown]
# ![image.png](attachment:8202a912-410c-4da8-820c-5d92e9e47771.png)

# %%
# The gradient descent for logistic regression is the same as linear regression 
# is Linear regresion the same as logistic regression ?
# No, because the definition for the function f(x) has changed

# %% [markdown]
# ![image.png](attachment:8dbb74a7-2281-4e70-8471-a286c91ac0d6.png)
