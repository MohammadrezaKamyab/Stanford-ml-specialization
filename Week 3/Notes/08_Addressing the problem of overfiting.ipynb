# %%
# imagin that you have an overfit house price prediction model

# %% [markdown]
# ![image.png](attachment:5bfb82d2-a10b-462f-9bb3-3d9a9f0f65e6.png)

# %%
# One way to address overfitting is to collect more data
# With more training example, the model learns to fit a function that is less wiggly therefore you can fit a high order polynomial
# if you have enough training set

# %% [markdown]
# ![image.png](attachment:458d2f7e-d630-4266-b779-25215b45402c.png)

# %%
# But collecting more data is always not an option, maybe there isn't more data

# %%
# Second option is to use fewer features
# if you have alot of features and a few insufficient data then your algorithm overfit to your training set
# Choosing only subset of important feature is called feature selection
# Disadvantage = useful features could be lost

# %% [markdown]
# ![image.png](attachment:2f602f9d-dd18-4c72-97fb-9c4df4d2779e.png)

# %%
# regularization
# if you have a high order polynomial and an overfitting model to your training set
# You could see that the parameters are relatively large
# if you were to eliminate one feature, you set the parameter to zero

# %%
# Regularzation is a way to reduce the impact of some features without eliminating the feature
# Regularization lets you keep all the features, but it prevent the features to have overly large effect that cause overfitting

# %% [markdown]
# ![image.png](attachment:7398c955-7f94-43ca-9442-20b0178635eb.png)

# %%
# by convension we normaly reduce the size of wj parameters and not b
# it doesn't matter if you regularize b or not, it doesn't effect that much

# %% [markdown]
# ![image.png](attachment:72b97921-33f5-4347-acbc-9db2e25404c1.png)
