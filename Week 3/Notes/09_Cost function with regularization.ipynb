# %% [markdown]
# ![image.png](attachment:666b167e-473e-46ae-a51e-67146c296811.png)

# %%
# quadratic function fits the data well
# fourth order polynomial ends up with a model overfitting to the data

# %%
# But if we were to make w3 and w4 really small

# %% [markdown]
# ![image.png](attachment:1fbf1982-702f-4ceb-89b1-89fefd6c3b94.png)

# %%
# lets say instead of minimizing this function

# %% [markdown]
# ![image.png](attachment:31f13fcf-5501-4371-9cce-fdee1c98764d.png)

# %%
# we modify the cost function to

# %% [markdown]
# ![image.png](attachment:5b4ce647-986d-42c5-a513-0adb7fee9936.png)

# %%
# if w3 and w4 are large then you're penelizing the model therefore the only way to make this cost function really small
# is to make w3 and w4 small
# therefore when you minimize this function you end up with w3 and w4 close to zero 
# therefore we're nearly canceling out the effect of w3, w4
# then we end up with a curve close to quadratic funciton

# %%
# more generally if you have n features, you may not know which are the most important features or which one penelize 
# so the way regularization is implemented is to penelize all of the wj paramters a bit and then shrink all of the wj terms 
# and this result in more smoother, simpler, less wigly 
# function and less prone to overfitting

# %%
# Imagin that you have 100 features and because you don't know which of these paramters going to be important ones
# we penelize all of them a bit and shrink all of them by adding this new term

# %% [markdown]
# ![image.png](attachment:22048068-efca-457e-8ae6-c76b5dffed21.png)

# %%
# lambda is the regularization paramter
# similar to alpha now you have to choose a number for lambda. lambda > 0 
# we divide lambda by 2m to scale both term 
# by scaling both term it's easier to set lambda. if you pick a lambda and the training set gets bigger the same lambda is going to work
# by convension we're not regularizing parameter b for being large
# some other algorithm also implement

# %% [markdown]
# ![image.png](attachment:995b0d25-201b-4ca8-b214-7bf98fb7f845.png)

# %% [markdown]
# ![image.png](attachment:cd2f82e9-e0ab-4035-8cfd-37991b20d785.png)

# %%
# we're going to minimize the mean squared error cost and regularization term
# Minimizaing the first term encourges the gradient descent to minimize error (difference between prediction and the actual value)
# Minimizing the second term algorithm tries to keep wj small which result in avoiding overfitting
# lambda controls how you balance between these two goal, let's see how

# %%
# if lambda = 0, then you're not using regulazation at all and that cause into overfitting into the data

# %% [markdown]
# ![image.png](attachment:3672cecd-67f1-4648-851a-bd6f5b6f27b2.png)

# %%
# if lambda was really really large number
# lambda = 10 to the power 10
# then you placing a really heavy weight on the second term (regularization) tried to make wj really small 
# so you end up with wj = close to zero

# %% [markdown]
# ![image.png](attachment:69eae8ad-481a-40cd-afef-bc8947f1a800.png)

# %%
# This result in underfitting the data
