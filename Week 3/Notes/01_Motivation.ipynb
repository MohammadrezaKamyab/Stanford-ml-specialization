# %% [markdown]
# * Logistic Regression is one of the most popular and widely used algorithm
# ![image.png](attachment:38cff771-6ff6-4b49-a925-3d82c7a7a391.png)
# ---
# * in These examples the variable you want to predict can be one of the two possible values **No** or **Yes**
# ![image.png](attachment:8f901e37-530a-4d7c-9554-ed296dc1f593.png)
# ---
# * This Type of classification where there only two possible output is called **Binary Classification**
# ![image.png](attachment:b0f6ac8d-c19e-4919-9dbc-f48656730c30.png)
# ---
# * We often designate classes as **No, Yes**, **True, False**, **0, 1**
# ![image.png](attachment:2f29c617-e116-4e0e-813f-59ec011f6759.png)
# ---
# * we call 0 , false , no class -> **Negative Class**
# * We call 1, True, Yes Class -> **Positive Class**

# %% [markdown]
# ---
# * Let's take a look at training set where 0 means **Benign** and 1 means **Malignant**
# ![image.png](attachment:6f35b128-b5ff-4a24-96e0-4e07776ad3c3.png)
# * You could fit a straight line into the data Using Linear regression
# * But Linear regression predicts all numbers between 0 and 1
# * But Here we want to predict **categories**
# * One Thing we can Try is to pick Threshold for example 0.5 so if model outputs a number below 0.5 then you predict y_hat = 0 and if
# if the model predicts equal or above 0.5 then you predict y_hat = 1
# ![image.png](attachment:54df785c-daf9-4d79-9e86-b1433b20f1e3.png)

# %% [markdown]
# ---
# * It turns out that threshold = 0.5 intersects the best fit line at this point
# ![image.png](attachment:39c1d46c-12d8-460b-a7a2-b7b109359feb.png)
#
# * if you draw a line in that point, everything to the left ends up with prediction 0 and to the right ends up with prediction 1
# ![image.png](attachment:2290f402-f2bf-4187-a3a3-3a60d1c7da0f.png)
#
# ---

# %% [markdown]
# * Let's add a new data to the training set
# ![image.png](attachment:25c56c44-2822-4296-85d3-d69364550978.png)
#
# * Now the Best fit line for linear regression changes to
# ![image.png](attachment:01e1c052-89d4-4c34-9e73-0130092c9375.png)
#
# * If you use Threshold of 0.5 everything to the left ends up with prediction 0 and to right ends up with 1
# ![image.png](attachment:36f68994-a9ef-4133-b473-8365fcdf040f.png)
#
# There are some data that **misclassified**

# %% [markdown]
# ---
# ![image.png](attachment:46aeba48-c8ae-4f6e-b89a-32c1389b3cb7.png)
# * This green dividing Line is class **Decision Boundary**

# %% [markdown]
# ---
# *Logistic Regression is used for **classification** although it has Regression in it
# * **Logistic Regression is Used to solve Binary classification problem where the output is 0 or 1**
