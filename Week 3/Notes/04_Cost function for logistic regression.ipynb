# %% [markdown]
# # Cost Function for Logistic Regression
# - Given a training set how to choose w = [w1, w2,...,wn] and b

# %% [markdown]
# ## Squared Error Cost function for Logistic Regression ???
#
# - Cost function for **Linear regression** is always **a Convex** Function with **One Global Minimum**
# ![image.png](attachment:22829ef6-6a3b-451c-9d99-7fb197ca7798.png)
# - If you use Squared Error Cost function for **Logistic Regression** You end up with a **non-convex** function with **Multiple local Minimum**
# ![image.png](attachment:4ad39932-e555-46d9-8e57-da3f27aedee7.png)

# %%
## Squared Error Cost function is not good for Logistic regression

# %% [markdown]
# ## Cost function for Logistic Regression
# ![image.png](attachment:55072d8e-ef46-4f5e-9dd1-babda1f70ae7.png)
# - inside the summation we changed the equation to
# ![image.png](attachment:69e54503-0497-4e62-af59-e9ea17bc0075.png)
# * This is Called **Loss** function with inputs **f_wb** and the actual **target value y**
# * <em><strong>Loss function measures how well you're doing on ONE TRAINING example and by summing up Losses you get Cost function</strong></em>

# %% [markdown]
# ---
# # Logistic Loss Function
# - Gets the input f(x) and true value y
# ![image.png](attachment:7b358400-b0d9-4b75-880f-4c0f90b5937e.png)

# %% [markdown]
# ### Plot LOG (f)
# ![image.png](attachment:cd8d0949-1f15-477b-8935-c8abb5d24c59.png)

# %% [markdown]
# ### Plot -LOG (f)
# ![image.png](attachment:4d5e50ad-8aae-4e3c-b009-5c3fe8cfd4c1.png)

# %%
# it intersections the horizontal axis at x = 1

# %% [markdown]
# - f is the output of logistic regression
# - therefore 0 < f < 1
# - Therefore The only part of the function that is relevant is
# ![image.png](attachment:9161fddc-5fdd-437a-88d7-3e51ff88b37f.png)

# %% [markdown]
# ![image.png](attachment:4bbfb3ac-5a57-45e5-a7a2-60c22cee5b2b.png)
# - if model predicts Y-hat **close to 1** and **Y = 1** then loss is **very small and close to zero**
# - if model predicts Y-hat **0.1** and **Y = 1** then loss is **very big, getting close to infinity**
# ![image.png](attachment:045b095a-eeae-4d71-9cbb-d1a052092160.png)

# %% [markdown]
# ---
# ### **Let's look at when Y = 0**
# ![image.png](attachment:fa85f122-aea8-48ef-8f97-063ba8f074a0.png)
# - because logistic regression predicts between 0 and 1 then
# ![image.png](attachment:2c7bf138-68ab-4f65-9702-ae88d720a6b9.png)

# %% [markdown]
# **The further the prediction f_wb(x) is from target y the higher the loss**
# ![image.png](attachment:cb301ce9-e6d0-4129-b08f-bdf0a4e950aa.png)

# %% [markdown]
# ![image.png](attachment:b10918db-85f1-4c14-b924-3b46daa97013.png)
