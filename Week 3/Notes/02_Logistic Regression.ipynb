# %% [markdown]
# # Logistic Regression

# %%
# Logistic Regression is single Most Widely used classification algorithm in the world

# %% [markdown]
# Let's Classify if a Tumor is **Malignant** or **Benign**
# ![image.png](attachment:5d6aa420-4f24-4513-a9ab-7d994fa52fed.png)
#
# * The y axis takes values 0 and 1 because it's a classification problem

# %% [markdown]
# ---
# * Logistic Regression Fits a curve line into the data (S shaped curve)
# ![image.png](attachment:86e35992-d3b0-4bae-8c83-a49130d9fe88.png)
# ---

# %% [markdown]
# if a patient comes with this tumor size
# ![image.png](attachment:5b1b33d0-c608-4d2f-b24e-2ec0e1435345.png)
#
# * Then it's **more likely** to be Benign
# ---

# %% [markdown]
# ### Sigmoid Function also Known as Logistic Function
# * Sigmoid Function looks like this
#   ![image.png](attachment:282f04ca-3069-4fac-ba83-ae3f8da6f53d.png)
# ---

# %% [markdown]
# ### Sigmoid Function
# ![image.png](attachment:1c1720db-5585-4e35-b318-575af1364ed5.png)
# ---

# %% [markdown]
# ---
# * if **z** is really **large** then 1 / (1.0000001) = 0.99999998 then it's closer to **1**
# * if **z** is really **small** then 1 / 10000000000 = 0.000000001 then it's closer to **0**
# * if **z = 0** then 1 / 1 + 1 = **0.5**
# ---

# %% [markdown]
# ## Step One : Store regression model in Z
# ![image.png](attachment:ab0778aa-d6ea-4470-83b6-88af148be92f.png)

# %% [markdown]
# ## Step Two : Pass Z to Sigmoid Function
# ![image.png](attachment:e62dac19-5941-4e02-8ae2-f52958c30d97.png)

# %% [markdown]
# ## Step Three : Put Two Equation together
# ![image.png](attachment:55e61b9a-7937-4df3-8444-14ebaff90c3a.png)

# %%
# This is Logistic Regression model

# %% [markdown]
# ## Interpretation of logistic regression output
# ![image.png](attachment:c5a7b3a5-b60a-4200-bccd-cbfcdb28fc74.png)
# * Given the input x. What is the **Probability of that class to be 1**

# %% [markdown]
# ---
# ---
# ![image.png](attachment:b437487d-ee4a-4a3e-88aa-ebdf0879523b.png)

# %% [markdown]
# ![image.png](attachment:a5504f03-6c9e-4885-8bc8-1b62024c99e2.png)
# *
